# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv('CouponAreaData.csv')
data
# Out:
#                            Names   Minimum   Maximum  Mean/Mode  \
# 0                        aerosol  0.000133  0.000256   0.000247
# 1                 foam ambiguous  0.000079  0.000079   0.000079
# 2                     foam spray  0.000962  1.440000   0.118187
# 3                        fogging  0.000262  0.092900   0.071103
# 4                     fumigation  0.000025  0.102200   0.005860
# 5              fumigation/liquid  0.001161  0.001161   0.001161
# 6   liquid soaked gauze covering  0.000600  0.000600   0.000600
# 7       liquid soaked gauze wipe  0.000600  0.000600   0.000600
# 8                            gel  0.000078  0.001425   0.000976
# 9                      immersion  0.000078  0.000078   0.000078
# 10                        liquid  0.000100  0.005625   0.002698
# 11              liquid ambiguous  0.000078  0.006400   0.000143
# 12                liquid dropper  0.000133  0.000133   0.000133
# 13              liquid immersion  0.000025  0.002500   0.000819
# 14                  liquid spray  0.000078  1.440000   0.039679
# 15                   liquid wipe  0.017700  0.129600   0.096927
# 16                      physical  0.000028  0.126451   0.004336
#
#     Standard Deviation
# 0         3.280000e-05
# 1         2.750000e-20
# 2         3.571036e-01
# 3         3.958705e-02
# 4         1.972920e-02
# 5         4.410000e-19
# 6         1.100000e-19
# 7         1.740000e-18
# 8         6.732500e-04
# 9         0.000000e+00
# 10        2.638815e-03
# 11        5.025110e-04
# 12        0.000000e+00
# 13        8.947840e-04
# 14        1.935174e-01
# 15        4.731640e-02
# 16        2.182341e-02

# %%
fig, ax = plt.subplots(figsize = (15, 10))
x = np.arange(data.shape[0])
ax.set_xticks(x)
ax.set_xticklabels(data['Names'], rotation = 45)
for tick in ax.xaxis.get_major_ticks():
    tick.label.set_horizontalalignment('right')

ax.set_ylim(-0.3, 0.5)

for column in data.columns[1:-2]:
    ax.scatter(x, data[column])

ax.errorbar(x, data['Mean/Mode'], yerr = data['Standard Deviation'], 
            fmt = 's', color = 'black', zorder = 0, alpha = 0.2, lw = 10, capsize = 10, capthick = 2)

ax.legend(data.columns[1:-2])
plt.savefig('couponarea.svg',bbox_inches="tight")
