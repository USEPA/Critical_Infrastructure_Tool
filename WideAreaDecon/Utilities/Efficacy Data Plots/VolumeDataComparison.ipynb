# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv('VolumeData.csv')
data
# Out:
#                            Names   Minimum     Maximum    Mean/Mode  \
# 0                 foam ambiguous   0.05000     0.05000     0.050000
# 1                     foam spray   1.01000  5700.00000  1555.823182
# 2                     fumigation   0.00417     0.01024     0.006930
# 3              fumigation/liquid   0.08000     0.16000     0.150000
# 4   liquid soaked gauze covering   0.80000     0.80000     0.800000
# 5       liquid soaked gauze wipe   0.80000     0.80000     0.800000
# 6                            gel   0.05000     2.00000     1.350000
# 7                         liquid   0.00500     0.25000     0.172407
# 8               liquid ambiguous   0.05000     2.00000     0.465924
# 9               liquid immersion  10.00000    10.00000    10.000000
# 10                  liquid spray   0.05000  7600.00000   464.860085
#
#     Standard Deviation
# 0         2.110000e-17
# 1         2.597501e+03
# 2         2.619938e-03
# 3         2.688086e-02
# 4         1.120000e-16
# 5         1.780000e-15
# 6         9.750000e-01
# 7         8.100197e-02
# 8         7.700989e-01
# 9         0.000000e+00
# 10        1.676510e+03

# %%
fig, ax = plt.subplots(figsize = (15, 10))
x = np.arange(data.shape[0])
ax.set_xticks(x)
ax.set_xticklabels(data['Names'], rotation = 45)
for tick in ax.xaxis.get_major_ticks():
    tick.label.set_horizontalalignment('right')

ax.set_ylim(-1500, 8000)

for column in data.columns[1:-2]:
    ax.scatter(x, data[column])

ax.errorbar(x, data['Mean/Mode'], yerr = data['Standard Deviation'], 
            fmt = 's', color = 'black', zorder = 0, alpha = 0.2, lw = 10, capsize = 10, capthick = 2)

ax.legend(data.columns[1:-2])
plt.savefig('volume.svg',bbox_inches="tight")
