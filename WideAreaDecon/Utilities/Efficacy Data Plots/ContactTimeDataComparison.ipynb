# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv('ContactTimeData.csv')
data
# Out:
#                            Names       Minimum       Maximum     Mean/Mode  \
# 0                        aerosol  1.000000e+01    419.401993     88.564309
# 1             aqueous suspension  0.000000e+00    120.000000     21.084906
# 2                 foam ambiguous  4.980000e+00   1440.000000    278.330000
# 3                     foam spray  3.000000e+01    120.000000     40.000000
# 4                        fogging  1.200000e+02   1380.000000    907.235294
# 5                     fumigation  0.000000e+00  20160.000000    719.609275
# 6              fumigation/liquid  7.200000e+03  20160.000000  11880.000000
# 7   liquid soaked gauze covering  0.000000e+00    360.000000     80.856383
# 8       liquid soaked gauze wipe  0.000000e+00     60.000000     18.896552
# 9                            gel  1.000000e+00     30.000000     13.444444
# 10                     immersion  1.000000e+01     10.000000     10.000000
# 11                        liquid  5.000000e-01   7200.000000    662.538217
# 12              liquid ambiguous  4.980000e+00   1440.000000     92.483165
# 13                liquid dropper  3.000000e+00      3.000000      3.000000
# 14              liquid immersion  3.330000e-15   1440.000000     56.575242
# 15                  liquid spray  3.952874e-01  10080.000000   1167.731877
# 16             liquid suspension  0.000000e+00  20160.000000    180.936564
# 17                   liquid wipe  3.000000e+00     30.000000      7.162162
# 18                      physical  0.000000e+00  40320.000000   2578.169616
# 19                  solid powder  2.000000e+01    100.000000     60.000000
# 20                    suspension  5.000000e+00   2880.000000    598.750000
#
#     Standard Deviation
# 0           127.549863
# 1            27.871354
# 2           528.276594
# 3            16.699498
# 4           391.121316
# 5          1497.698799
# 6          5001.697776
# 7           114.151355
# 8            20.502176
# 9            12.620530
# 10            0.000000
# 11         1811.100597
# 12          312.749867
# 13            0.000000
# 14          206.628643
# 15         2878.145857
# 16         1412.305497
# 17            8.146279
# 18         4601.969005
# 19           31.622777
# 20          978.763661

# %%
fig, ax = plt.subplots(figsize = (15, 10))
x = np.arange(data.shape[0])
ax.set_xticks(x)
ax.set_xticklabels(data['Names'], rotation = 45)
for tick in ax.xaxis.get_major_ticks():
    tick.label.set_horizontalalignment('right')

ax.set_ylim(-3000, 23000)

for column in data.columns[1:-2]:
    ax.scatter(x, data[column])

ax.errorbar(x, data['Mean/Mode'], yerr = data['Standard Deviation'], 
            fmt = 's', color = 'black', zorder = 0, alpha = 0.2, lw = 10, capsize = 10, capthick = 2)

ax.legend(data.columns[1:-2])
plt.savefig('contacttime.svg',bbox_inches="tight")
