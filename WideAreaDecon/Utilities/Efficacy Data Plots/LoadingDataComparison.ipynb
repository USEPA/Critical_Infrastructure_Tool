# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv('LoadingData.csv')
data
# Out:
#                           Names    Minimum    Maximum     Mean/Mode  \
# 0                       aerosol    1000000    1000000  1.000000e+06
# 1                foam ambiguous    4600000    4600000  4.600000e+06
# 2             fumigation/liquid    1000000   10000000  8.312500e+06
# 3  liquid soaked gauze covering    5000000  100000000  2.925532e+07
# 4      liquid soaked gauze wipe        300  100000000  1.245828e+07
# 5                           gel   10000000   10000000  1.000000e+07
# 6                     immersion   10000000   10000000  1.000000e+07
# 7              liquid ambiguous       1000  100000000  8.316552e+07
# 8                liquid dropper  100000000  100000000  1.000000e+08
#
#    Standard Deviation
# 0        0.000000e+00
# 1        0.000000e+00
# 2        3.569020e+06
# 3        4.187168e+07
# 4        3.257600e+07
# 5        0.000000e+00
# 6        0.000000e+00
# 7        3.559182e+07
# 8        0.000000e+00

# %%
fig, ax = plt.subplots(figsize = (15, 10))
x = np.arange(data.shape[0])
ax.set_xticks(x)
ax.set_xticklabels(data['Names'], rotation = 45)
for tick in ax.xaxis.get_major_ticks():
    tick.label.set_horizontalalignment('right')

ax.set_ylim(-30000000, 126000000)

for column in data.columns[1:-2]:
    ax.scatter(x, data[column])

ax.errorbar(x, data['Mean/Mode'], yerr = data['Standard Deviation'], 
            fmt = 's', color = 'black', zorder = 0, alpha = 0.2, lw = 10, capsize = 10, capthick = 2)

ax.legend(data.columns[1:-2])
plt.savefig('loading.svg',bbox_inches="tight")
