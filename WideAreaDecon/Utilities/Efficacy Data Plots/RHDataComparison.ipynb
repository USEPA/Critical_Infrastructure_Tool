# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv('RelativeHumidityData.csv')
data
# Out:
#                            Names  Minimum  Maximum     Mean/Mode  \
# 0                        aerosol       50       50     50.000000
# 1             aqueous suspension       50       50     50.000000
# 2                 foam ambiguous       50       50     50.000000
# 3                     foam spray       40       80     50.444444
# 4                        fogging       50       50     50.000000
# 5                     fumigation       30       95     68.963686
# 6              fumigation/liquid       50       50     50.000000
# 7   liquid soaked gauze covering       50       50     50.000000
# 8       liquid soaked gauze wipe       50       50     50.000000
# 9                            gel       45       50     46.666667
# 10                     immersion       50       50     50.000000
# 11                        liquid       50       50     50.000000
# 12              liquid ambiguous       50       50     50.000000
# 13                liquid dropper       50       50     50.000000
# 14              liquid immersion       50       50     50.000000
# 15                  liquid spray       40       80     50.405650
# 16             liquid suspension       50       50     50.000000
# 17                   liquid wipe       50    20333  18140.243240
# 18                      physical       35       90     64.216167
# 19                  solid powder       50       50     50.000000
#
#     Standard Deviation
# 0             0.000000
# 1             0.000000
# 2             0.000000
# 3             8.729533
# 4             0.000000
# 5            14.095256
# 6             0.000000
# 7             0.000000
# 8             0.000000
# 9             2.500000
# 10            0.000000
# 11            0.000000
# 12            0.000000
# 13            0.000000
# 14            0.000000
# 15            5.675905
# 16            0.000000
# 17         6385.090304
# 18           16.045406
# 19            0.000000

# %%
fig, ax = plt.subplots(figsize = (15, 10))
x = np.arange(data.shape[0])
ax.set_xticks(x)
ax.set_xticklabels(data['Names'], rotation = 45)
for tick in ax.xaxis.get_major_ticks():
    tick.label.set_horizontalalignment('right')

ax.set_ylim(25, 100)

for column in data.columns[1:-2]:
    ax.scatter(x, data[column])

ax.errorbar(x, data['Mean/Mode'], yerr = data['Standard Deviation'], 
            fmt = 's', color = 'black', zorder = 0, alpha = 0.2, lw = 10, capsize = 10, capthick = 2)

ax.legend(data.columns[1:-2])
plt.savefig('relativehumidity.svg',bbox_inches="tight")
